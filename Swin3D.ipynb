# %% [markdown]
# ## This code was run using the PyTorch 2.4.0 Kernel on Rivanna HPC
#
# We use WandB (weights and biases) to log our model performance and generate the figures in our paper. It is encouraged that those reproducing these results create a wandb account, install wandb, and use `wandb login` to set up logging. However, if you would like to skip this, please remove code involving wandb from the training loop and the notebook should run without problem.

# %%
import wandb

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split

import torchvision
from torchvision.models.video import swin_transformer, Swin3D_B_Weights

import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
dirpath = 'Cardiac-Video-Sequence/' # Change to location of this folder on your device
X = torch.load(dirpath+'X_upscaled_tensor.pt')
Y = torch.load(dirpath+'Y_tensor.pt')

# %%
X.shape, Y.shape
# Out:
# (torch.Size([112, 25, 3, 224, 224]), torch.Size([112, 126]))

# %%
# Need to reshape to [B, C, N, W, H] for Swin Transformer
X = X.permute(0, 2, 1, 3, 4)

# %%
X.shape, Y.shape
# Out:
# (torch.Size([112, 3, 25, 224, 224]), torch.Size([112, 126]))

# %%
class TOCDataset(Dataset):
    def __init__(self, X, Y):
        """
        X: torch.Tensor of shape (N, 25, 224, 224) - videos
        Y: torch.Tensor of shape (N, 126) - target curves
        """
        self.X = X
        self.Y = Y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        video = self.X[idx]
        curve = self.Y[idx]
        return video, curve

# %%
# Create dataset and data loader
dataset = TOCDataset(X, Y)
train_size = int(6/7 * len(dataset))
test_size = len(dataset) - train_size
bs = 8

train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=bs, shuffle=False)

# %%
# Custom weight initialization to scale down weights
def init_weights(layer):
    if isinstance(layer, nn.Linear):
        nn.init.uniform_(layer.weight, a=-0.01, b=0.01)  # Small weights
        if layer.bias is not None:
            nn.init.constant_(layer.bias, 0)

# %%
model = swin_transformer.swin3d_b(weights=None)  
# change model head to output a 126-dim vector corresponding to the TOS curve
model.head = nn.Linear(model.head.in_features, 126)
model = model.apply(init_weights)

# %%
# READ:
#    ATTEMPTED EFFORT TO FREEZE TRANSFORMER AND TRAIN ITS HEAD AS AN MLP FOR BETTER PERFORMANCE
#    FAILED EXPERIMENT, BAD RESULTS
_ = """
# Initialize SwinTransformer3D base model
model = swin_transformer.swin3d_b(weights=Swin3D_B_Weights.KINETICS400_V1)  
model.head = nn.Sequential(
    nn.Linear(model.head.in_features, 512), 
    nn.Tanh(),
    nn.BatchNorm1d(512),
    nn.Linear(512, 256),
    nn.Tanh(),
    nn.BatchNorm1d(256),
    nn.Linear(256, 126),
    nn.Tanh()
)

model.head.apply(init_weights)

for name, param in model.named_parameters():
    if not name.startswith("head"):  # Freeze all parameters except the head
        param.requires_grad = False
"""

# %%
# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
# Loss function, optimizer
criterion = nn.MSELoss()  # Use MSELoss for regression
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
# Initialize W&B
wandb.init(
    project="MLIA",  # Replace with your W&B project name
    name="SwinFrozen",
    config={
        "learning_rate": optimizer.param_groups[0]['lr'],
        # READ: Max_norm was used for gradient clipping, but we found it ineffective
        #"max_norm": 0.5,
        "num_epochs": 500,
        "patience": 15,
    },
)
config = wandb.config

# Early stopping setup
patience = config.patience
best_train_loss = float("inf")
patience_counter = 0
best_model_weights = None

# Function to calculate parameter norm
def calculate_param_norm(model, norm_type=2):
    total_norm = 0.0
    for param in model.parameters():
        if param.requires_grad:
            param_norm = param.norm(norm_type)
            total_norm += param_norm.item() ** norm_type
    return total_norm ** (1.0 / norm_type)

# Training loop
num_epochs = config.num_epochs
for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for videos, curves in train_loader:
        videos, curves = videos.to(device), curves.to(device)

        # Forward pass
        outputs = model(videos)
        loss = criterion(outputs, curves)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()

        # Clip gradients
        #torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=config.max_norm)

        optimizer.step()

        total_loss += loss.item()
    
    avg_train_loss = total_loss / len(train_loader)
    
    model.eval()
    valid_loss = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            valid_loss += criterion(outputs, labels).item()
    avg_valid_loss = valid_loss / len(test_loader)
    model.train()

    # Calculate parameter norm
    param_norm = calculate_param_norm(model)

    # Log metrics to W&B
    wandb.log({
        "epoch": epoch + 1,
        "train_loss": avg_train_loss,
        "valid_loss": avg_valid_loss,
        "param_norm": param_norm,  # Log parameter norm
    })

    # Early stopping logic
    if avg_train_loss < best_train_loss:
        best_train_loss = avg_train_loss
        patience_counter = 0
        best_model_weights = model.state_dict()  # Save the best model weights
        # Save best model to W&B
        wandb.run.summary["best_train_loss"] = best_train_loss
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"Early stopping triggered. Validation loss did not improve for {patience} epochs.")
            wandb.run.summary["early_stopping_epoch"] = epoch + 1
            break

    # Print progress every 5 epochs
    if epoch % 5 == 0:
        print(f"Epoch {epoch}/{num_epochs} - Train Loss: {avg_train_loss:.4f}, Param Norm: {param_norm:.4f}")

# Restore the best model weights after training
if best_model_weights is not None:
    model.load_state_dict(best_model_weights)
    print("Restored the best model weights.")

wandb.finish()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: bae9wk (crg). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/sfs/weka/scratch/bae9wk/SwinTransformer/wandb/run-20241210_215829-4gygh6gw</code>
# Syncing run <strong><a href='https://wandb.ai/crg/MLIA/runs/4gygh6gw' target="_blank">SwinFrozen</a></strong> to <a href='https://wandb.ai/crg/MLIA' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/crg/MLIA' target="_blank">https://wandb.ai/crg/MLIA</a>
#  View run at <a href='https://wandb.ai/crg/MLIA/runs/4gygh6gw' target="_blank">https://wandb.ai/crg/MLIA/runs/4gygh6gw</a>
# Epoch 0/500 - Train Loss: 1243.8012, Param Norm: 179.2417
# Epoch 5/500 - Train Loss: 946.5377, Param Norm: 179.3506
# Epoch 10/500 - Train Loss: 717.7220, Param Norm: 179.4363
# Epoch 15/500 - Train Loss: 560.8913, Param Norm: 179.5213
# Epoch 20/500 - Train Loss: 452.8597, Param Norm: 179.5995
# Epoch 25/500 - Train Loss: 377.6199, Param Norm: 179.6687
# Epoch 30/500 - Train Loss: 325.4140, Param Norm: 179.7283
# Epoch 35/500 - Train Loss: 290.1561, Param Norm: 179.7821
# Epoch 40/500 - Train Loss: 266.7515, Param Norm: 179.8259
# Epoch 45/500 - Train Loss: 252.1015, Param Norm: 179.8648
# Epoch 50/500 - Train Loss: 243.4253, Param Norm: 179.9241
# Epoch 55/500 - Train Loss: 237.9738, Param Norm: 179.9607
# Epoch 60/500 - Train Loss: 234.9080, Param Norm: 179.9783
# Epoch 65/500 - Train Loss: 233.2185, Param Norm: 179.9904
# Epoch 70/500 - Train Loss: 232.4601, Param Norm: 179.9996
# Epoch 75/500 - Train Loss: 232.1960, Param Norm: 180.0134
# Epoch 80/500 - Train Loss: 231.7030, Param Norm: 180.0433
# Epoch 85/500 - Train Loss: 231.5438, Param Norm: 180.0452
# Epoch 90/500 - Train Loss: 231.4771, Param Norm: 180.0465
# Epoch 95/500 - Train Loss: 231.4886, Param Norm: 180.0522
# Epoch 100/500 - Train Loss: 231.6778, Param Norm: 180.0625
# Epoch 105/500 - Train Loss: 233.1647, Param Norm: 180.0792
# Epoch 110/500 - Train Loss: 231.5241, Param Norm: 180.1196
# Epoch 115/500 - Train Loss: 231.6895, Param Norm: 180.1220
# Early stopping triggered. Validation loss did not improve for 15 epochs.
# Restored the best model weights.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>param_norm</td><td>▁▁▁▂▂▂▃▃▃▃▅▅▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████</td></tr><tr><td>train_loss</td><td>█▇▆▆▅▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_loss</td><td>█▇▆▆▅▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_train_loss</td><td>231.01052</td></tr><tr><td>early_stopping_epoch</td><td>119</td></tr><tr><td>epoch</td><td>119</td></tr><tr><td>param_norm</td><td>180.12336</td></tr><tr><td>train_loss</td><td>232.09388</td></tr><tr><td>valid_loss</td><td>238.71668</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SwinFrozen</strong> at: <a href='https://wandb.ai/crg/MLIA/runs/4gygh6gw' target="_blank">https://wandb.ai/crg/MLIA/runs/4gygh6gw</a><br/> View project at: <a href='https://wandb.ai/crg/MLIA' target="_blank">https://wandb.ai/crg/MLIA</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241210_215829-4gygh6gw/logs</code>

# %%
# Save weights as a tensor
torch.save(model.state_dict(), dirpath+'swin3d_weights.pth')

# %%
# Just used to test model loading

#model = swin_transformer.swin3d_b(weights=None)  
#model.head = nn.Linear(model.head.in_features, 126)
#model.load_state_dict(torch.load(dirpath+'swin3d_weights.pth'))
#model = model.to(device)

# %%
def plot_predictions(predictions, ground_truths, num_samples=16, path='fig.png'):
    num_samples = min(num_samples, len(predictions))
    indices = torch.randint(0, len(predictions), (num_samples,))  # Randomly select samples
    
    # Create a 5x5 grid of subplots
    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    axes = axes.flatten()  # Flatten the axes array to make indexing easier

    for i, idx in enumerate(indices):
        ax = axes[i]  # Get the current subplot axis
        ax.plot(ground_truths[idx].numpy(), label="True Curve", linestyle='--')
        ax.plot(predictions[idx].numpy(), label="Predicted Curve", linestyle='-')
        ax.set_title(f"Sample {i + 1}")
        ax.grid(True)
        
    plt.tight_layout()
    plt.savefig(path)
    plt.show()


# Function to evaluate the model on the test set and compute both MSE and R²
def evaluate_model(model, test_loader, device):
    model.eval()  # Set the model to evaluation mode
    total_mse = 0
    predictions = []
    ground_truths = []

    with torch.no_grad():
        for videos, curves in test_loader:
            videos, curves = videos.to(device), curves.to(device)
            
            # Forward pass
            outputs = model(videos)
            
            # Accumulate predictions and ground truth for plotting
            predictions.append(outputs.cpu())
            ground_truths.append(curves.cpu())
            
            # Compute MSE for the batch
            total_mse += nn.MSELoss()(outputs, curves).item()

    # Concatenate predictions and ground truths for plotting
    predictions = torch.cat(predictions, dim=0)
    ground_truths = torch.cat(ground_truths, dim=0)

    # Compute average MSE
    avg_mse = total_mse / len(test_loader)

    # Compute R² score
    total_r2 = 0
    for i in range(len(predictions)):
        total_r2 += r2_score(predictions[i], ground_truths[i])
    avg_r2 = total_r2 / len(predictions)

    return avg_mse, avg_r2, predictions, ground_truths

# %%
# Generate the plots and eval metrics

mse, r2,  predictions, ground_truths = evaluate_model(model, train_loader, device)
print(f"Train MSE: {mse:.4f}")
print(f"Train R²: {r2:.4f}")
plot_predictions(predictions, ground_truths, path='figs/swin_train.png')

mse, r2,  predictions, ground_truths = evaluate_model(model, test_loader, device)
print(f"Test MSE: {mse:.4f}")
print(f"Test R²: {r2:.4f}")

plot_predictions(predictions, ground_truths, path='figs/swin_test.png')
# Out:
# Train MSE: 231.4135
# Train R²: -0.1074
# Test MSE: 238.7167
# Test R²: -0.1424

# %% [markdown]
# ## Experiments end here
#
# Code below is an attempt by the experimenters to debug the Swin Transformer model and not necessary to the core results.

# %%
class VarianceTracker:
    def __init__(self, model):
        self.model = model
        self.hooks = []
        self.layer_stats = {}
        
    def hook_fn(self, name):
        def fn(module, input, output):
            if isinstance(output, torch.Tensor):
                # Reshape output to [batch_size, -1] to handle different layer shapes
                flat_output = output.view(output.size(0), -1)
                
                # Calculate variance between different samples in batch
                sample_means = flat_output.mean(dim=1)
                between_sample_var = sample_means.var()
                
                # Calculate average variance within samples
                within_sample_var = flat_output.var(dim=1).mean()
                
                self.layer_stats[name] = {
                    'between_sample_var': between_sample_var.item(),
                    'within_sample_var': within_sample_var.item(),
                    'shape': output.shape
                }
        return fn
    
    def register_hooks(self):
        # Clear any existing hooks
        self.remove_hooks()
        
        # Register new hooks
        for name, module in self.model.named_modules():
            if isinstance(module, (nn.Linear, nn.LayerNorm, nn.ReLU)):
                hook = module.register_forward_hook(self.hook_fn(name))
                self.hooks.append(hook)
    
    def remove_hooks(self):
        for hook in self.hooks:
            hook.remove()
        self.hooks = []
    
    def analyze_batch(self, batch):
        self.layer_stats = {}
        
        # Forward pass
        with torch.no_grad():
            output = self.model(batch)
        
        # Print statistics
        print("\nLayer Variance Analysis:")
        print("-" * 50)
        for name, stats in self.layer_stats.items():
            print(f"\nLayer: {name}")
            print(f"Shape: {stats['shape']}")
            print(f"Between-sample variance: {stats['between_sample_var']:.8f}")
            print(f"Within-sample variance: {stats['within_sample_var']:.8f}")
            if stats['between_sample_var'] > 0:
                ratio = stats['within_sample_var'] / stats['between_sample_var']
                print(f"Within/Between ratio: {ratio:.4f}")
        
        return output

# Usage example:
tracker = VarianceTracker(model)
tracker.register_hooks()

# Get a batch of videos
batch_videos, _ = next(iter(train_loader))
batch_videos = batch_videos.to(device)

# Analyze the batch
_ = tracker.analyze_batch(batch_videos)

# Clean up
tracker.remove_hooks()
# Out:
# Layer Variance Analysis:
# --------------------------------------------------
#
# Layer: patch_embed.norm
# Shape: torch.Size([8, 13, 56, 56, 128])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.04926629
# Within/Between ratio: 150358239.1527
#
# Layer: features.0.0.norm1
# Shape: torch.Size([8, 13, 56, 56, 128])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.03307639
# Within/Between ratio: 132344268.0367
#
# Layer: features.0.0.norm2
# Shape: torch.Size([8, 13, 56, 56, 128])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.80576730
# Within/Between ratio: 721454558.4780
#
# Layer: features.0.0.mlp.0
# Shape: torch.Size([8, 13, 56, 56, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.10177027
# Within/Between ratio: 1470698050516.2129
#
# Layer: features.0.0.mlp.3
# Shape: torch.Size([8, 13, 56, 56, 128])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.04143303
# Within/Between ratio: 71767363542675.2031
#
# Layer: features.0.1.norm1
# Shape: torch.Size([8, 13, 56, 56, 128])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.07952605
# Within/Between ratio: 66163101031.4681
#
# Layer: features.0.1.norm2
# Shape: torch.Size([8, 13, 56, 56, 128])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.34109426
# Within/Between ratio: 5628218774375.3496
#
# Layer: features.0.1.mlp.0
# Shape: torch.Size([8, 13, 56, 56, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.04170545
# Within/Between ratio: 5259089784277.9248
#
# Layer: features.0.1.mlp.3
# Shape: torch.Size([8, 13, 56, 56, 128])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01830288
# Within/Between ratio: 42583790514244856.0000
#
# Layer: features.1.norm
# Shape: torch.Size([8, 13, 28, 28, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.04188704
# Within/Between ratio: 4354344406.3946
#
# Layer: features.1.reduction
# Shape: torch.Size([8, 13, 28, 28, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00023624
# Within/Between ratio: 143287739009.9342
#
# Layer: features.2.0.norm1
# Shape: torch.Size([8, 13, 28, 28, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01350622
# Within/Between ratio: 148505478843.7649
#
# Layer: features.2.0.norm2
# Shape: torch.Size([8, 13, 28, 28, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.25372207
# Within/Between ratio: 20301113061373.6055
#
# Layer: features.2.0.mlp.0
# Shape: torch.Size([8, 13, 28, 28, 1024])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.02337647
#
# Layer: features.2.0.mlp.3
# Shape: torch.Size([8, 13, 28, 28, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.02387632
# Within/Between ratio: 2217048155966706432.0000
#
# Layer: features.2.1.norm1
# Shape: torch.Size([8, 13, 28, 28, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.05228875
# Within/Between ratio: 538944826489880.3125
#
# Layer: features.2.1.norm2
# Shape: torch.Size([8, 13, 28, 28, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.14664242
# Within/Between ratio: 284016549535455.6875
#
# Layer: features.2.1.mlp.0
# Shape: torch.Size([8, 13, 28, 28, 1024])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01588316
#
# Layer: features.2.1.mlp.3
# Shape: torch.Size([8, 13, 28, 28, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.03493126
# Within/Between ratio: 4510576033168703488.0000
#
# Layer: features.3.norm
# Shape: torch.Size([8, 13, 14, 14, 1024])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00549643
# Within/Between ratio: 31776945292498.0117
#
# Layer: features.3.reduction
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00001421
# Within/Between ratio: 17276480302574.4062
#
# Layer: features.4.0.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00318274
# Within/Between ratio: 5767061999182.5225
#
# Layer: features.4.0.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.02538895
#
# Layer: features.4.0.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.04653216
#
# Layer: features.4.0.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01426160
#
# Layer: features.4.1.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00287252
# Within/Between ratio: 46365132497182280.0000
#
# Layer: features.4.1.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.03588183
#
# Layer: features.4.1.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.02872233
#
# Layer: features.4.1.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00707936
#
# Layer: features.4.2.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00626673
#
# Layer: features.4.2.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.04128696
#
# Layer: features.4.2.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01847886
#
# Layer: features.4.2.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00568128
#
# Layer: features.4.3.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00621864
#
# Layer: features.4.3.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.04910256
#
# Layer: features.4.3.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01768252
#
# Layer: features.4.3.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00464661
#
# Layer: features.4.4.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01714060
#
# Layer: features.4.4.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000001
# Within-sample variance: 0.06124121
# Within/Between ratio: 4926655.9894
#
# Layer: features.4.4.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000004
# Within-sample variance: 0.01676503
# Within/Between ratio: 461019.3906
#
# Layer: features.4.4.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.02117993
# Within/Between ratio: 3213475861.7163
#
# Layer: features.4.5.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000003
# Within-sample variance: 0.01641143
# Within/Between ratio: 568075.4728
#
# Layer: features.4.5.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000002
# Within-sample variance: 0.09873353
# Within/Between ratio: 4165518.6532
#
# Layer: features.4.5.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000008
# Within-sample variance: 0.01869581
# Within/Between ratio: 235510.9742
#
# Layer: features.4.5.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.03017007
# Within/Between ratio: 27884629.3874
#
# Layer: features.4.6.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.03530046
# Within/Between ratio: 276617240.9654
#
# Layer: features.4.6.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000002
# Within-sample variance: 0.13466698
# Within/Between ratio: 5891882.9649
#
# Layer: features.4.6.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000009
# Within-sample variance: 0.01483656
# Within/Between ratio: 171896.1685
#
# Layer: features.4.6.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000001
# Within-sample variance: 0.04673818
# Within/Between ratio: 6197937.2444
#
# Layer: features.4.7.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000140
# Within-sample variance: 0.03565948
# Within/Between ratio: 25518.7931
#
# Layer: features.4.7.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000009
# Within-sample variance: 0.18916929
# Within/Between ratio: 2056358.1517
#
# Layer: features.4.7.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000006
# Within-sample variance: 0.01650033
# Within/Between ratio: 274042.5839
#
# Layer: features.4.7.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.03771637
# Within/Between ratio: 74901665.7333
#
# Layer: features.4.8.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000174
# Within-sample variance: 0.05320318
# Within/Between ratio: 30549.6736
#
# Layer: features.4.8.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.23393077
# Within/Between ratio: 165906215.1080
#
# Layer: features.4.8.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000004
# Within-sample variance: 0.01179494
# Within/Between ratio: 273320.9519
#
# Layer: features.4.8.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.02284987
# Within/Between ratio: 356065679.2207
#
# Layer: features.4.9.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000209
# Within-sample variance: 0.05317803
# Within/Between ratio: 25427.0895
#
# Layer: features.4.9.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000018
# Within-sample variance: 0.28974974
# Within/Between ratio: 1655117.0288
#
# Layer: features.4.9.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000001
# Within-sample variance: 0.00806384
# Within/Between ratio: 716045.1074
#
# Layer: features.4.9.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01366975
# Within/Between ratio: 220251227.1683
#
# Layer: features.4.10.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000380
# Within-sample variance: 0.06607845
# Within/Between ratio: 17411.7286
#
# Layer: features.4.10.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000193
# Within-sample variance: 0.31716064
# Within/Between ratio: 164519.4722
#
# Layer: features.4.10.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000004
# Within-sample variance: 0.00724925
# Within/Between ratio: 191028.7160
#
# Layer: features.4.10.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00561668
# Within/Between ratio: 8060722.3338
#
# Layer: features.4.11.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000445
# Within-sample variance: 0.07317757
# Within/Between ratio: 16445.3192
#
# Layer: features.4.11.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00001255
# Within-sample variance: 0.57292676
# Within/Between ratio: 45660.8129
#
# Layer: features.4.11.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000005
# Within-sample variance: 0.00742845
# Within/Between ratio: 149951.3553
#
# Layer: features.4.11.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00178499
# Within/Between ratio: 5149884.6559
#
# Layer: features.4.12.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000587
# Within-sample variance: 0.09341271
# Within/Between ratio: 15900.5587
#
# Layer: features.4.12.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00003086
# Within-sample variance: 1.47334480
# Within/Between ratio: 47744.5262
#
# Layer: features.4.12.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000013
# Within-sample variance: 0.00655982
# Within/Between ratio: 50770.4518
#
# Layer: features.4.12.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00625441
# Within/Between ratio: 9370936.8401
#
# Layer: features.4.13.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000555
# Within-sample variance: 0.10690767
# Within/Between ratio: 19272.9229
#
# Layer: features.4.13.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00004156
# Within-sample variance: 2.42200136
# Within/Between ratio: 58281.7466
#
# Layer: features.4.13.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000022
# Within-sample variance: 0.00667019
# Within/Between ratio: 29964.9067
#
# Layer: features.4.13.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00756497
# Within/Between ratio: 36273298.7946
#
# Layer: features.4.14.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000506
# Within-sample variance: 0.13031708
# Within/Between ratio: 25729.8420
#
# Layer: features.4.14.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00004604
# Within-sample variance: 3.39955473
# Within/Between ratio: 73843.1867
#
# Layer: features.4.14.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000032
# Within-sample variance: 0.00694628
# Within/Between ratio: 21665.3262
#
# Layer: features.4.14.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01414941
# Within/Between ratio: 116325185.9593
#
# Layer: features.4.15.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000313
# Within-sample variance: 0.16345224
# Within/Between ratio: 52241.3044
#
# Layer: features.4.15.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00003951
# Within-sample variance: 3.64305401
# Within/Between ratio: 92199.1409
#
# Layer: features.4.15.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000203
# Within-sample variance: 0.01774531
# Within/Between ratio: 8757.8191
#
# Layer: features.4.15.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01484847
# Within/Between ratio: 11293792.4284
#
# Layer: features.4.16.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000271
# Within-sample variance: 0.18010646
# Within/Between ratio: 66402.1973
#
# Layer: features.4.16.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00003980
# Within-sample variance: 2.84775162
# Within/Between ratio: 71555.4575
#
# Layer: features.4.16.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000263
# Within-sample variance: 0.03359935
# Within/Between ratio: 12784.6432
#
# Layer: features.4.16.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.02667063
# Within/Between ratio: 63116551.5278
#
# Layer: features.4.17.norm1
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000161
# Within-sample variance: 0.20136547
# Within/Between ratio: 125128.6297
#
# Layer: features.4.17.norm2
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00002122
# Within-sample variance: 1.90058911
# Within/Between ratio: 89585.4802
#
# Layer: features.4.17.mlp.0
# Shape: torch.Size([8, 13, 14, 14, 2048])
# Between-sample variance: 0.00000166
# Within-sample variance: 0.10250998
# Within/Between ratio: 61866.1897
#
# Layer: features.4.17.mlp.3
# Shape: torch.Size([8, 13, 14, 14, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.29144019
# Within/Between ratio: 237983801.1632
#
# Layer: features.5.norm
# Shape: torch.Size([8, 13, 7, 7, 2048])
# Between-sample variance: 0.00004260
# Within-sample variance: 0.26975548
# Within/Between ratio: 6332.7869
#
# Layer: features.5.reduction
# Shape: torch.Size([8, 13, 7, 7, 1024])
# Between-sample variance: 0.00000438
# Within-sample variance: 0.98363674
# Within/Between ratio: 224555.0803
#
# Layer: features.6.0.norm1
# Shape: torch.Size([8, 13, 7, 7, 1024])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00458520
# Within/Between ratio: 2405440.5530
#
# Layer: features.6.0.norm2
# Shape: torch.Size([8, 13, 7, 7, 1024])
# Between-sample variance: 0.00000096
# Within-sample variance: 0.02119355
# Within/Between ratio: 22114.8900
#
# Layer: features.6.0.mlp.0
# Shape: torch.Size([8, 13, 7, 7, 4096])
# Between-sample variance: 0.00000001
# Within-sample variance: 0.01600428
# Within/Between ratio: 1436847.3899
#
# Layer: features.6.0.mlp.3
# Shape: torch.Size([8, 13, 7, 7, 1024])
# Between-sample variance: 0.00000009
# Within-sample variance: 0.30864447
# Within/Between ratio: 3543558.2728
#
# Layer: features.6.1.norm1
# Shape: torch.Size([8, 13, 7, 7, 1024])
# Between-sample variance: 0.00000005
# Within-sample variance: 0.00600033
# Within/Between ratio: 124469.9117
#
# Layer: features.6.1.norm2
# Shape: torch.Size([8, 13, 7, 7, 1024])
# Between-sample variance: 0.00000009
# Within-sample variance: 0.03478035
# Within/Between ratio: 374029.8915
#
# Layer: features.6.1.mlp.0
# Shape: torch.Size([8, 13, 7, 7, 4096])
# Between-sample variance: 0.00000004
# Within-sample variance: 0.01071193
# Within/Between ratio: 281029.8060
#
# Layer: features.6.1.mlp.3
# Shape: torch.Size([8, 13, 7, 7, 1024])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.11397457
# Within/Between ratio: 1498865572.9069
#
# Layer: norm
# Shape: torch.Size([8, 13, 7, 7, 1024])
# Between-sample variance: 0.00000004
# Within-sample variance: 0.00079614
# Within/Between ratio: 18082.1475
#
# Layer: head.0
# Shape: torch.Size([8, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.00010799
# Within/Between ratio: 374485.9135
#
# Layer: head.1
# Shape: torch.Size([8, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.56182301
# Within/Between ratio: 9214920145062.4473
#
# Layer: head.2.layers.0
# Shape: torch.Size([8, 512])
# Between-sample variance: 0.00000001
# Within-sample variance: 0.00476132
# Within/Between ratio: 466006.4474
#
# Layer: head.2.layers.1
# Shape: torch.Size([8, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.61344576
# Within/Between ratio: 22669720392500.1172
#
# Layer: head.2.layers.2
# Shape: torch.Size([8, 512])
# Between-sample variance: 0.00000007
# Within-sample variance: 0.38463908
# Within/Between ratio: 5196100.7462
#
# Layer: head.2.layers.4
# Shape: torch.Size([8, 512])
# Between-sample variance: 0.00000031
# Within-sample variance: 0.00633689
# Within/Between ratio: 20242.2473
#
# Layer: head.2.layers.5
# Shape: torch.Size([8, 512])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.61346334
# Within/Between ratio: 2909570677930.2368
#
# Layer: head.3
# Shape: torch.Size([8, 512])
# Between-sample variance: 0.00000037
# Within-sample variance: 1.44027209
# Within/Between ratio: 3885401.7909
#
# Layer: head.4
# Shape: torch.Size([8, 256])
# Between-sample variance: 0.00000003
# Within-sample variance: 0.06964090
# Within/Between ratio: 2154810.6122
#
# Layer: head.5
# Shape: torch.Size([8, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.61599195
# Within/Between ratio: 29930859194205.9609
#
# Layer: head.6.layers.0
# Shape: torch.Size([8, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.01370892
# Within/Between ratio: 121313439.2884
#
# Layer: head.6.layers.1
# Shape: torch.Size([8, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.61568892
# Within/Between ratio: 319593937173532.8750
#
# Layer: head.6.layers.2
# Shape: torch.Size([8, 256])
# Between-sample variance: 0.00000001
# Within-sample variance: 0.54600978
# Within/Between ratio: 67944150.9826
#
# Layer: head.6.layers.4
# Shape: torch.Size([8, 256])
# Between-sample variance: 0.00004853
# Within-sample variance: 0.03154910
# Within/Between ratio: 650.1371
#
# Layer: head.6.layers.5
# Shape: torch.Size([8, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.61617833
# Within/Between ratio: 17385210533.8307
#
# Layer: head.7
# Shape: torch.Size([8, 256])
# Between-sample variance: 0.00000000
# Within-sample variance: 0.61771387
# Within/Between ratio: 3034322967.9020
#
# Layer: head.8
# Shape: torch.Size([8, 256])
# Between-sample variance: 0.00001425
# Within-sample variance: 0.24046613
# Within/Between ratio: 16871.9430
#
# Layer: head.9
# Shape: torch.Size([8, 126])
# Between-sample variance: 0.00000168
# Within-sample variance: 0.01810521
# Within/Between ratio: 10757.5993
